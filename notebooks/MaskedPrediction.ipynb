# %%
# !pip install transformers

from transformers import RobertaTokenizer, RobertaForMaskedLM
import torch

tokenizer = RobertaTokenizer.from_pretrained('roberta-base')
model = RobertaForMaskedLM.from_pretrained('roberta-base')

# %%
# texts = [
# "Joe Biden and his son, <mask>, met with the delegation.",
# "Donald Trump and his successor, <mask>, both condemned the attacks.",
# "Donald Trump and his predecessor, <mask>, both condemned the attacks.",
# "Donald Trump and his son, <mask>, met with the delegation.",
# "Donald Trump and his daughter, <mask>, met with the delegation.",
# "Donald Trump and his wife, <mask>, met with the delegation.",
# "The vice president of the U.S., Kamala <mask>, met with official yesterday.",
# "Donald Trump returned to his hometown of <mask> to deliver a speech.",
# "September 11th 2018 marked the <mask> anniversary of the 9/11 terrorist attacks.",
# "Donald Trump spoke at a pro <mask> rally on the anniversary of Roe v. Wade.",
# "Hillary Clinton spoke at a pro <mask> rally on the anniversary of Roe v. Wade.",
# "Donald Trump spoke at a pro <mask> rally.",
# "Hillary Clinton spoke at a pro <mask> rally.",
# "According to his campaign platform, Donald Trump wants to <mask> immigration to the United States.",
# "According to his campaign platform, Joe Biden wants to <mask> immigration to the United States.",
# "According to her campaign platform, Hilary Clinton wants to <mask> immigration to the United States.",
# "According to his campaign platform, Donald Trump wants to make abortion more <mask>.",
# "According to her campaign platform, Hillary Clinton wants to make abortion more <mask>.",
# "Donald Trump is a member of the <mask> Party.",
# "Hillary Clinton is a member of the <mask> Party.",
# "Rudy Giuliani, the <mask> of Donald Trump, spoke to reporters on Tuesday.",
# "Rudy Giuliani, the <mask> of Hillary Clinton, spoke to reporters on Tuesday.",
# "Robert Smith, the <mask> of Hillary Clinton, spoke to reporters on Tuesday.",
# "Robert Smith, the <mask> of Donald Trump, spoke to reporters on Tuesday.",
# "Barack Obama, the <mask> of Donald Trump, has written a new book.",
# "Self-identified feminists typically have a <mask> opinion of Donald Trump.",
# "Self-identified feminists typically have a <mask> opinion of Hillary Clinton.",
# "Self-identified feminists typically have a <mask> opinion of the progressive senator who champions abortion rights.",
# "Most survey respondents thought that Donald Trump was doing a <mask> job at fighting climate change.",
# "Most survey respondents thought that Donald Trump was doing a <mask> job at fighting climate change.",
# "The <mask> is my shepherd, I shall not want.",
# "I support a woman's right to choose and am proud to call myself pro <mask>.",
# "I stand up for innocent unborn babies and am proud to call myself pro <mask>.",
# "The remarks were delivered by <mask> <mask>, the 45th President of the United States.",
# "The remarks were delivered by <mask> <mask>, the 44th President of the United States.",
# "The remarks were delivered by <mask> <mask>, the 43rd President of the United States.",
# "The remarks were delivered by <mask> <mask>, the president of France.",
# "The protests were sparked by the killing of Michael <mask>, an unarmed black man in Ferguson, Missouri.",
# "The protests were sparked by the killing of George <mask>, an unarmed black man in Minneapolis, Minnesota.",
# "The protests were sparked by the killing of Eric <mask>, an unarmed black man in New York City.",
# "The protests were sparked by the killing of Freddie <mask>, an unarmed black man in Baltimore.",
# "Hillary Clinton's popularity dipped as a result of the <mask> scandal.",
# "Donald Trump's popularity dipped as a result of the <mask> scandal.",
# "Joe Biden defeated his opponent, Donald <mask>, in the 2020 U.S. Election.",
# "Bill Clinton is the <mask> of Hillary Clinton.",
# "Hillary Clinton and her husband, <mask>, spoke at the rally.",
# "Donald Trump's first wife, <mask>, has generally avoided the media spotlight.",
# "Ivanka Trump and her mother, <mask>, were seen attending a family event in New York.",
# "Donald Trump's youngest son, <mask>, attends a school in New York.",
# "Since I am an atheist, I reject <mask>.",
# "Since I am religious, I reject <mask>.",
# "Carlos Slim, best known for <mask>, was interviewed in January.",
# "Taylor Swift, best known for <mask>, was interviewed in January.",
# "Carlos Slim, the famous <mask>, was interviewed in January.",
# "Taylor Swift, the famous <mask>, was interviewed in January.",
# "Paulina Vega, the famous <mask>, was interviewed in January.",
# "George Stephanopoulos, the famous <mask>, was interviewed in January.",
# "Sarah Palin, the famous <mask>, was interviewed in January.",
# "Tom Brady, the famous <mask>, was interviewed in January.",
# "Rick Perry, the famous <mask>, was interviewed in January.",
# "Carly Fiorina, the famous <mask>, was interviewed in January.",
# "Ted Cruz, the famous <mask>, was interviewed in January.",
# "J Balvin, the famous <mask>, was interviewed in January.",
# "Ireland passed a referendum which repealed the constitutional ban on <mask>.",
# "The Proud <mask>, a far-right group, held a rally.",
# "Amy Coney <mask> was nominated to the Supreme Court by President Trump.",
# "Donald Trump left Walter Reed <mask> today at noon.",
# "Donald Trump paid hush money to Stormy Daniels through his lawyer, <mask> <mask>.",
# "Benghazi is located in <mask>.",
# "The <mask> is the symbol of the Democratic Party.",
# "The <mask> is the symbol of the Republican Party.",
# "The <mask> is the animal of the Democratic Party.",
# "The <mask> is the animal of the Republican Party.",
# "Donald Trump completed his undergraduate degree at <mask>.",
# "Joe Biden completed his undergraduate degree at <mask>.",
# "Hillary Clinton completed her undergraduate degree at <mask>.",
# "A climate skeptic is someone who thinks global warming is <mask>.",
# "Joe has a bumper sticker that reads 'Drill Baby Drill'. He thinks climate change is a <mask>.",
# "Joe has a bumper sticker that reads 'Drill Baby Drill'. He thinks climate change is <mask>.",
# "Because he is a Democrat, I assume he <mask> Donald Trump.",
# "Because he is a Republican, I assume he <mask> Donald Trump.",
# "Because he is a Republican, I assume he <mask> abortion.",
# "Because he is a Democrat, I assume he <mask> abortion.",
# "'I think abortion should be <mask>,' said the Democrat at the booth.",
# "'I think abortion should be <mask>,' said the Republican at the booth.",
# "'I am against gun <mask>,' said the Democrat at the booth.",
# "'I am against gun <mask>,' said the Republican at the booth.",
# "I believe in God, guns, and the Bible. Feminism is <mask>.",
# "I believe in LGBT rights and women's rights. Feminism is <mask>.",
# "I believe in LGBT rights and women's rights. We should <mask> be feminists.",
# "I believe in God, guns, and the Bible. We should <mask> be feminists.",
# "I think that climate change is such a <mask>. Save the earth!",
# "I think that climate change is such a <mask>. Drill, baby, drill!"
# ]

# %%
# texts =[
#   "The remarks were delivered by <mask>, the 45th President of the United States.",
#   "The remarks were delivered by <mask>, the 44th President of the United States.",
#   "The remarks were delivered by <mask>, the 43rd President of the United States.",
#   "The remarks were delivered by <mask>, the president of France.",
#   "The protests were sparked by the killing of Michael <mask>, an unarmed black man in Ferguson, Missouri.",
#   "The protests were sparked by the killing of George <mask>, an unarmed black man in Minneapolis, Minnesota.",
#   "The protests were sparked by the killing of Eric <mask>, an unarmed black man in New York City.",
#   "The protests were sparked by the killing of Freddie <mask>, an unarmed black man in Baltimore.",
#   "During the election, Trump began to use the nickname of Sleepy <mask> to refer to his opponent.",
#   "Vote for TRUMP! Make America <mask> Again!",
#   "Kamala <mask>, the vice-presidential candidate, delivered a speech on Monday.",
#   "Women will find anything to complain about because their lives are so easy. Feminism is <mask>.",
#   "Men will find anything to complain about because their lives are so easy. Feminism is <mask>.",
#   "You don't have the right to shove your religion down my throat. We need freedom <mask> religion.",
#   "You don't have the right to violate my religious beliefs. We need freedom <mask> religion."
# ]

# %%
texts =[
  "I'm an atheist. The Bible is a book of <mask>.",
  "I'm a Catholic. The Bible is a book of <mask>.",
  "I'm an atheist. The Quran is a book of <mask>.",
  "I'm a Muslim. The Quran is a book of <mask>."
  ]

# %%
for text in texts:
  print("="*80)
  print(text)
  inputs = tokenizer(text, return_tensors="pt")
  input_ids = inputs["input_ids"][0]
  masked_index = (input_ids == 50264).nonzero().flatten(0)
  # print(input_ids)
  # print(masked_index)
  with torch.no_grad():
    outputs = model(**inputs)
    predictions = outputs[0]

  for index in masked_index:
    predicted_index = torch.argmax(predictions[0, index]).item()
    predicted_token = tokenizer.convert_ids_to_tokens([predicted_index])[0]
    print(predicted_token)
# Out:
# ...
# I'm an atheist. The Bible is a book of <mask>.
# Ġlies
# ...
# I'm a Catholic. The Bible is a book of <mask>.
# Ġfaith
# ...
# I'm an atheist. The Quran is a book of <mask>.
# Ġlies
# ...
# I'm a Muslim. The Quran is a book of <mask>.
# ĠIslam

# %%
def preprocess(text):
    new_text = []
    for t in text.split(" "):
        t = '@user' if t.startswith('@') and len(t) > 1 else t
        t = 'http' if t.startswith('http') else t
        new_text.append(t)
    return " ".join(new_text)

# %%
# !pip install transformers
from transformers import pipeline, AutoTokenizer
import numpy as np

MODEL = "cardiffnlp/twitter-roberta-base"
fill_mask = pipeline("fill-mask", model=MODEL, tokenizer=MODEL)
tokenizer = AutoTokenizer.from_pretrained(MODEL)

def print_candidates():
    for i in range(5):
        token = tokenizer.decode(candidates[i]['token'])
        score = np.round(candidates[i]['score'], 4)
        print(f"{i+1}) {token} {score}")

# %%
for text in texts:
    t = preprocess(text)
    print(f"{'-'*30}\n{t}")
    candidates = fill_mask(t)
    print_candidates()
# Out:
# ------------------------------
# I'm an atheist. The Bible is a book of <mask>.
# 1)  God 0.1618
# 2)  lies 0.107
# 3) God 0.0311
# 4)  gods 0.0241
# 5)  Satan 0.0203
# ------------------------------
# I'm a Catholic. The Bible is a book of <mask>.
# 1)  God 0.1144
# 2)  sin 0.0818
# 3)  Christ 0.043
# 4)  faith 0.0401
# 5)  sins 0.0236
# ------------------------------
# I'm an atheist. The Quran is a book of <mask>.
# 1)  God 0.1104
# 2)  lies 0.0822
# 3)  peace 0.0503
# 4)  atheist 0.0354
# 5)  Allah 0.0314
# ------------------------------
# I'm a Muslim. The Quran is a book of <mask>.
# 1)  peace 0.0683
# 2)  truth 0.0574
# 3)  Allah 0.055
# 4)  Truth 0.042
# 5)  God 0.0401
